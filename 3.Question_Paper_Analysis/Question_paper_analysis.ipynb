# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('class_marks.csv')
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 0     4.0    6.0
# 1     NaN    NaN
# 2     NaN    NaN
# 3     2.0    NaN
# ...

# %%
df.shape
# Out:
# (86, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Total   86 non-null     int64
#  1   Q1aM4   85 non-null     float64
#  2   Q1bM6   73 non-null     float64
#  3   Q2aM6   72 non-null     float64
#  4   Q2bM4   75 non-null     float64
#  5   Q3aM5   52 non-null     float64
#  6   Q3bM5   51 non-null     float64
#  7   Q4aM3   32 non-null     float64
#  8   Q4bM7   26 non-null     float64
#  9   Q5M10   56 non-null     float64
#  10  Q6aM4   33 non-null     float64
#  11  Q6bM6   28 non-null     float64
# dtypes: float64(11), int64(1)
# memory usage: 8.2 KB

# %%
df.isnull().sum()
# Out:
# Total     0
# Q1aM4     1
# Q1bM6    13
# Q2aM6    14
# Q2bM4    11
# Q3aM5    34
# Q3bM5    35
# Q4aM3    54
# Q4bM7    60
# Q5M10    30
# Q6aM4    53
# Q6bM6    58
# dtype: int64

# %%
df.fillna(0,inplace=True)
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    0.0    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    0.0    0.0    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    0.0    0.0    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    0.0    0.0    0.0
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    0.0    0.0   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    0.0    0.0    0.0
# 82     27    2.0    2.0    5.0    3.0    0.0    0.0    0.0    0.0    7.0
# 83     37    4.0    6.0    6.0    2.0    0.0    0.0    0.0    0.0    9.0
# 84     28    4.0    0.0    5.0    4.0    5.0    4.0    0.0    0.0    6.0
# 85     29    4.0    6.0    0.0    0.0    0.0    0.0    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 0     4.0    6.0
# 1     0.0    0.0
# 2     0.0    0.0
# 3     2.0    0.0
# ...

# %%
df.isnull().sum()
# Out:
# Total    0
# Q1aM4    0
# Q1bM6    0
# Q2aM6    0
# Q2bM4    0
# Q3aM5    0
# Q3bM5    0
# Q4aM3    0
# Q4bM7    0
# Q5M10    0
# Q6aM4    0
# Q6bM6    0
# dtype: int64

# %%
df["Q1"]=df["Q1aM4"]+df["Q1bM6"] 
df["Q2"]=df["Q2aM6"]+df["Q2bM4"] 
df["Q3"]=df["Q3aM5"]+df["Q3bM5"] 
df["Q4"]=df["Q4aM3"]+df["Q4bM7"] 
df["Q5"]=df["Q5M10"] 
df["Q6"]=df["Q6aM4"]+df["Q6bM6"] 
df.drop(["Q1aM4","Q1bM6","Q2aM6","Q2bM4","Q3aM5","Q3bM5","Q4aM3","Q4bM7","Q5M10","Q6aM4","Q6bM6"],axis=1,inplace=True)
df
# Out:
#     Total    Q1    Q2    Q3   Q4    Q5    Q6
# 0      37   9.0  10.0   3.0  5.0   8.0  10.0
# 1      32   7.0   7.0   0.0  9.0   9.0   0.0
# 2      33   9.0   6.0  10.0  0.0   8.0   0.0
# 3      24  10.0   9.0   4.0  0.0   0.0   2.0
# 4      36   9.0   8.0   9.0  0.0  10.0   0.0
# ..    ...   ...   ...   ...  ...   ...   ...
# 81     32   9.0   7.0   8.0  0.0   0.0  10.0
# 82     27   4.0   8.0   0.0  0.0   7.0   8.0
# 83     37  10.0   8.0   0.0  0.0   9.0  10.0
# 84     28   4.0   9.0   9.0  0.0   6.0   0.0
# 85     29  10.0   0.0   0.0  8.0   7.0   5.0
#
# [86 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Total   86 non-null     int64
#  1   Q1      86 non-null     float64
#  2   Q2      86 non-null     float64
#  3   Q3      86 non-null     float64
#  4   Q4      86 non-null     float64
#  5   Q5      86 non-null     float64
#  6   Q6      86 non-null     float64
# dtypes: float64(6), int64(1)
# memory usage: 4.8 KB

# %%
sns.histplot(df['Total'], kde=True, bins=10, color='blue').set(title='Distribution of Total Scores', xlabel='Total Marks', ylabel='Frequency')
# Out:
# [Text(0.5, 1.0, 'Distribution of Total Scores'),
#  Text(0.5, 0, 'Total Marks'),
#  Text(0, 0.5, 'Frequency')]

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df['Q1'], y=df['Q2'])
plt.title('Scatter Plot of Q1 vs Q2')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x=df['Total'])
plt.title('Count of Each Category')
plt.xticks(rotation=45)
plt.show()

# %%
def assign_grade(marks):
    if marks >= 50:
        return 'A'
    elif marks >= 40:
        return 'B'
    elif marks >= 30:
        return 'C'
    elif marks >= 20:
        return 'D'
    else:
        return 'F'
df['Grade'] = df['Total'].apply(assign_grade)
df.head()
# Out:
#    Total    Q1    Q2    Q3   Q4    Q5    Q6 Grade
# 0     37   9.0  10.0   3.0  5.0   8.0  10.0     C
# 1     32   7.0   7.0   0.0  9.0   9.0   0.0     C
# 2     33   9.0   6.0  10.0  0.0   8.0   0.0     C
# 3     24  10.0   9.0   4.0  0.0   0.0   2.0     D
# 4     36   9.0   8.0   9.0  0.0  10.0   0.0     C

# %%
plt.figure(figsize=(6, 6))
df['Grade'].value_counts().plot.pie(autopct='%1.1f%%', cmap='coolwarm', startangle=90)
plt.ylabel('')
plt.title('Distribution of Grades')
plt.show()

# %%
def pass_or_fail(marks):
    return 'Pass' if marks >= 18 else 'Fail'
df['pass_fail'] = df['Total'].apply(pass_or_fail)
df.head()
# Out:
#    Total    Q1    Q2    Q3   Q4    Q5    Q6 Grade pass_fail
# 0     37   9.0  10.0   3.0  5.0   8.0  10.0     C      Pass
# 1     32   7.0   7.0   0.0  9.0   9.0   0.0     C      Pass
# 2     33   9.0   6.0  10.0  0.0   8.0   0.0     C      Pass
# 3     24  10.0   9.0   4.0  0.0   0.0   2.0     D      Pass
# 4     36   9.0   8.0   9.0  0.0  10.0   0.0     C      Pass

# %%
plt.figure(figsize=(6, 5))
sns.countplot(x=df['pass_fail'], palette=['green', 'red'])
plt.title('Pass vs Fail Count')
plt.xlabel('Result')
plt.ylabel('Number of Students')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(y=df['Total'])
plt.title('Box Plot of Total Marks')
plt.ylabel('Marks')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df[['Q1', 'Q2', 'Q3','Q4','Q5','Q6']])
plt.title('Box Plot of Subject-Wise Marks')
plt.ylabel('Marks')
plt.show()

# %%
def performance_category(grade):
    if grade == 'A':
        return 'Excellent'
    elif grade == 'B':
        return 'Good'
    elif grade == 'C':
        return 'Average'
    else:
        return 'Poor'

df['Performance'] = df['Grade'].apply(performance_category)
df
# Out:
#     Total    Q1    Q2    Q3   Q4    Q5    Q6 Grade pass_fail Performance
# 0      37   9.0  10.0   3.0  5.0   8.0  10.0     C      Pass     Average
# 1      32   7.0   7.0   0.0  9.0   9.0   0.0     C      Pass     Average
# 2      33   9.0   6.0  10.0  0.0   8.0   0.0     C      Pass     Average
# 3      24  10.0   9.0   4.0  0.0   0.0   2.0     D      Pass        Poor
# 4      36   9.0   8.0   9.0  0.0  10.0   0.0     C      Pass     Average
# ..    ...   ...   ...   ...  ...   ...   ...   ...       ...         ...
# 81     32   9.0   7.0   8.0  0.0   0.0  10.0     C      Pass     Average
# 82     27   4.0   8.0   0.0  0.0   7.0   8.0     D      Pass        Poor
# 83     37  10.0   8.0   0.0  0.0   9.0  10.0     C      Pass     Average
# 84     28   4.0   9.0   9.0  0.0   6.0   0.0     D      Pass        Poor
# 85     29  10.0   0.0   0.0  8.0   7.0   5.0     D      Pass        Poor
#
# [86 rows x 10 columns]

# %%
plt.figure(figsize=(6, 6))
df['Performance'].value_counts().plot.pie(autopct='%1.1f%%', cmap='cool', startangle=90)
plt.ylabel('')
plt.title('Performance Distribution')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x=df['Grade'], palette='magma', order=['A', 'B', 'C', 'D', 'F'])
plt.title('Number of Students in Each Grade')
plt.xlabel('Grade')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 5))
df_grouped = df.groupby('Grade')[['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6']].mean()
df_grouped.T.plot(kind='bar', figsize=(10, 5), colormap='plasma')
plt.title('Average Marks Per Question by Grade')
plt.xlabel('Questions')
plt.ylabel('Average Marks')
plt.legend(title="Grade")
plt.show()
